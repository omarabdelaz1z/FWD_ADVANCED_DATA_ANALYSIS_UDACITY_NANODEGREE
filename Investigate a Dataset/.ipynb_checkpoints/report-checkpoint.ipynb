# %% [raw]
# # %notebook "insights/report.ipynb"

# %% [markdown]
# <h1><center><em>Investigate a Dataset Project</em></center></h1>
#
# ##### Author: Omar Abdelaziz
#
# ##### Date: Nov. 13 2020
#
#
#
# ### Introduction
#
# In the project, I decided to choose TMDb movies dataset. The dataset is collected from TMDb API and contains various information about 10,000 movies including many features such as cast members, genre of the movie, budget, revenue and more features.
#
#
#
# ### Dataset Limitations/Issues
#
#
# - Cast members are split by pipe **"|",** so it makes much effort to select a certain actor to check the most favorable actor loved by people.
#
# - The same thing applies to genres.
#
# - Many occurrences of bad encoding in two columns **cast** and **movie title**.
#
# - Missing values in movies' budget and revenue are considered limitation of the dataset
#
#
#
#
# Therefore, I have dealt with many questions were I needn't deal with such problems stated above.
#
#
#
# ### Here are the questions were came into my mind.
#
#
#
# - ##### 1. What is The Most Rated Movie per Year
#
# - ##### 2. Top Five Most Popular Directors Based On Movie Rating Count
#
# - ##### 3. Top Movies for Christopher Nolan and Quentin Tarantino
#
# - ##### 4. The longest movie in terms of runtime
#
# - ##### 5. What production companies that people watch their movies the most.
#
# - ##### 6. What kind of movies that the most production company produce?
#
# - ##### 7. Most Favorable/Loved Movie Genre
#
# - ##### 8. Do Movie Budget Increase Among The Years?
#
#
#
# ### And this is my approach to investigate the questions respectively.
# ##### 1. I grouped the movies by their release year, then selected the highest vote average for a movie.
#
# ![most_rated_movie_per_year](https://i.imgur.com/PuD1ctQ.png)
#
# ##### 2. Movies are grouped by the movie director then aggregated the number of people votes by summing this number and reach the result.
#
# ![Top_five_directors](https://i.imgur.com/TcMmgLI.png)
#
# ##### 3.  I selected each director of the two and retrieved top 3 movies based on the highest average rate.
#
# ![Top-Movies-for-tarantino](https://i.imgur.com/PlelN8D.png)
#
# ![Top-movies-for-nolan](https://i.imgur.com/EB4YLIa.png)
#
# ##### 4. I selected  the movie where the the maximum runtime of all movies is that movie.
#
# ![most-movie](https://i.imgur.com/8Is38UM.png)
#
# ##### 5. I grouped the data by production companies that have the most vote counts.
#
# ![top-production-companies](https://i.imgur.com/3vtQRUQ.png)
#
# ##### 6. We can see that people love super hero movies produced by Marvel Studios.
#
# ![Marvel-movies](https://i.imgur.com/P2rD9uQ.png)
#
# ##### 7. Movies are grouped by their genres then selected the highest engaging numbers.
#
# ![most-genres](https://i.imgur.com/8A2R1fx.png)
#
#
#
# ### Data Wrangling Efforts
#
# - Removed Duplicates - "Tekken Movie"
# - Removed Zero-Budget Movies
# - Removed Revenue Movies
# - Fixed Release Date of the movie, Year Column wasn't accurate.
# - Dropped Unnecessary Columns
# - Renamed dataset columns to be consistent.
#
#
#
# ### Visualization
#
# ### Top Production Companies
#
# ![top-production-companies](https://i.imgur.com/tTOJMI6.png)
#
#
# ### Movies Budget' Increasing..
# ![movie-budget](https://i.imgur.com/WE0NDmd.png)
